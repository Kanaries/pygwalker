# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
df = pd.read_csv('./bike_sharing_dc.csv', parse_dates=['date'])[:10]
strange_name = f"{''.join([chr(i) for i in range(1, 256)])}"
df[strange_name] = df['date']
df = df.set_index([strange_name, 'date'])
df.iloc[1, 4] = strange_name
df
# Out:
#                                                                month  season  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01      1  winter
#                                                    2011-01-01      1  winter
#                                                    2011-01-01      1  winter
#                                                    2011-01-01      1  winter
#                                                    2011-01-01      1  winter
#                                                    2011-01-01      1  winter
#                                                    2011-01-01      1  winter
#                                                    2011-01-01      1  winter
#                                                    2011-01-01      1  winter
#                                                    2011-01-01      1  winter
#
#                                                                hour  year  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01     0  2011
#                                                    2011-01-01     1  2011
#                                                    2011-01-01     2  2011
#                                                    2011-01-01     3  2011
#                                                    2011-01-01     4  2011
#                                                    2011-01-01     5  2011
#                                                    2011-01-01     6  2011
#                                                    2011-01-01     7  2011
#                                                    2011-01-01     8  2011
#                                                    2011-01-01     9  2011
#
#                                                                                                          holiday  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01                                                 no
# \t\n
#
# \r
#
#
#  !"#$%&'()*+...
#                                                    2011-01-01                                                 no
#                                                    2011-01-01                                                 no
#                                                    2011-01-01                                                 no
#                                                    2011-01-01                                                 no
#                                                    2011-01-01                                                 no
#                                                    2011-01-01                                                 no
#                                                    2011-01-01                                                 no
#                                                    2011-01-01                                                 no
#
#                                                                temperature  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01         3.28
#                                                    2011-01-01         2.34
#                                                    2011-01-01         2.34
#                                                    2011-01-01         3.28
#                                                    2011-01-01         3.28
#                                                    2011-01-01         3.28
#                                                    2011-01-01         2.34
#                                                    2011-01-01         1.40
#                                                    2011-01-01         3.28
#                                                    2011-01-01         7.04
#
#                                                                feeling_temp  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01        3.0014
#                                                    2011-01-01        1.9982
#                                                    2011-01-01        1.9982
#                                                    2011-01-01        3.0014
#                                                    2011-01-01        3.0014
#                                                    2011-01-01        1.0016
#                                                    2011-01-01        1.9982
#                                                    2011-01-01        1.0016
#                                                    2011-01-01        3.0014
#                                                    2011-01-01        7.0010
#
#                                                                humidity  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01      81.0
#                                                    2011-01-01      80.0
#                                                    2011-01-01      80.0
#                                                    2011-01-01      75.0
#                                                    2011-01-01      75.0
#                                                    2011-01-01      75.0
#                                                    2011-01-01      80.0
#                                                    2011-01-01      86.0
#                                                    2011-01-01      75.0
#                                                    2011-01-01      76.0
#
#                                                                winspeed  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01    0.0000
#                                                    2011-01-01    0.0000
#                                                    2011-01-01    0.0000
#                                                    2011-01-01    0.0000
#                                                    2011-01-01    0.0000
#                                                    2011-01-01    6.0032
#                                                    2011-01-01    0.0000
#                                                    2011-01-01    0.0000
#                                                    2011-01-01    0.0000
#                                                    2011-01-01    0.0000
#
#                                                                casual  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01       3
#                                                    2011-01-01       8
#                                                    2011-01-01       5
#                                                    2011-01-01       3
#                                                    2011-01-01       0
#                                                    2011-01-01       0
#                                                    2011-01-01       2
#                                                    2011-01-01       1
#                                                    2011-01-01       1
#                                                    2011-01-01       8
#
#                                                                registered  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01          13
#                                                    2011-01-01          32
#                                                    2011-01-01          27
#                                                    2011-01-01          10
#                                                    2011-01-01           1
#                                                    2011-01-01           1
#                                                    2011-01-01           0
#                                                    2011-01-01           2
#                                                    2011-01-01           7
#                                                    2011-01-01           6
#
#                                                                count  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01     16
#                                                    2011-01-01     40
#                                                    2011-01-01     32
#                                                    2011-01-01     13
#                                                    2011-01-01      1
#                                                    2011-01-01      1
#                                                    2011-01-01      2
#                                                    2011-01-01      3
#                                                    2011-01-01      8
#                                                    2011-01-01     14
#
#                                                                work yes or not  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01                0
#                                                    2011-01-01                0
#                                                    2011-01-01                0
#                                                    2011-01-01                0
#                                                    2011-01-01                0
#                                                    2011-01-01                0
#                                                    2011-01-01                0
#                                                    2011-01-01                0
#                                                    2011-01-01                0
#                                                    2011-01-01                0
#
#                                                               am or pm  \
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01       am
#                                                    2011-01-01       am
#                                                    2011-01-01       am
#                                                    2011-01-01       am
#                                                    2011-01-01       am
#                                                    2011-01-01       am
#                                                    2011-01-01       am
#                                                    2011-01-01       am
#                                                    2011-01-01       am
#                                                    2011-01-01       am
#
#                                                                Day of the week
# \t\n
#
# \r
#
#
#  !"#$%&'()*+,... date
# 2011-01-01                                         2011-01-01                6
#                                                    2011-01-01                6
#                                                    2011-01-01                6
#                                                    2011-01-01                6
#                                                    2011-01-01                6
#                                                    2011-01-01                6
#                                                    2011-01-01                6
#                                                    2011-01-01                6
#                                                    2011-01-01                6
#                                                    2011-01-01                6

# %%
import pygwalker as pyg
pyg.walk(df)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <body>
#     <!-- <script crossorigin src="https://unpkg.com/react@17/umd/react.development.js"></script>
#     <script crossorigin src="https://unpkg.com/react-dom@17/umd/react-dom.development.js"></script> -->
#     <!-- <script crossorigin src="graphic-walker.umd.js"></script> -->
#     <div id="gwalker-2" class="gwalker-container"></div>
#     <script>
#         var exports={};var process={env:{NODE_ENV:"production"} };var GraphicWalker=function(Ps){"use strict";var Bpt=Object.defineProperty;var Upt=(Ps,dr,wd)=>dr in Ps?Bpt(Ps,dr,{enumerable:!0,configurable:!0,writable:!0,value:wd}):Ps[dr]=wd;var jr=(Ps,dr,wd)=>(Upt(Ps,typeof dr!="symbol"?dr+"":dr,wd),wd);var dr=typeof globalThis<"u"?globalThis:typeof window<"u"?window:typeof global<"u"?global:typeof self<"u"?self:{};function wd(e){return e&&e.__esModule&&Object.prototype.hasOwnProperty.call(e,"default")?e.default:e}var J={},Lbe={get exports(){return J},set exports(e){J=e}},Un={};/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */var e3,pU;function e2(){if(pU)return e3;pU=1;var e=Object.getOwnPropertySymbols,t=Object.prototype.hasOwnProperty,n=Object.prototype.propertyIsEnumerable;function r(a){if(a==null)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(a)}function i(){try{if(!Object.assign)return!1;var a=new String("abc");if(a[5]="de",Object.getOwnPropertyNames(a)[0]==="5")return!1;for(var o={},s=0;s<10;s++)o["_"+String.fromCharCode(s)]=s;var l=Object.getOwnPropertyNames(o).map(function(f){return o[f]});if(l.join("")!=="0123456789")return!1;var u={};return"abcdefghijklmnopqrst".split("").forEach(function(f){u[f]=f}),Object.keys(Object.assign({},u)).join("")==="abcdefghijklmnopqrst"}catch{return!1}}return e3=i()?Object.assign:function(a,o){for(var s,l=r(a),u,f=1;f<arguments.length;f++){s=Object(arguments[f]);for(var d in s)t.call(s,d)&&(l[d]=s[d]);if(e){u=e(s);for(var h=0;h<u.length;h++)n.call(s,u[h])&&(l[u[h]]=s[u[h]])}}return l},e3}/** @license React v17.0.2
#  * react.production.min.js
#  *
#  * Copyright (c) Facebook, Inc. and its affiliates.
#  *
#  * This source code is licensed under the MIT license found in the
#  * LICENSE file in the root directory of this source tree.
#  */var hU;function Wbe(){if(hU)return Un;hU=1;var e=e2(),t=60103,n=60106;Un.Fragment=60107,Un.StrictMode=60108,Un.Profiler=60114;var r=60109,i=60110,a=60112;Un.Suspense=60113;var o=60115,s=60116;if(typeof Symbol=="function"&&Symbol.for){var l=Symbol.for;t=l("react.element"),n=l("react.portal"),Un.Fragment=l("react.fragment"),Un.StrictMode=l("react.strict_mode"),Un.Profiler=l("react.profiler"),r=l("react.provider"),i=l("react.context"),a=l("react.forward_ref"),Un.Suspense=l("react.suspense"),o=l("react.memo"),s=l("react.lazy")}var u=typeof Symbol=="function"&&Symbol.iterator;function f(z){return z===null||typeof z!="object"?null:(z=u&&z[u]||z["@@iterator"],typeof z=="function"?z:null)}function d(z){for(var te="https://reactjs.org/docs/error-decoder.html?invariant="+z,ue=1;ue<arguments.length;ue++)te+="&args[]="+encodeURIComponent(arguments[ue]);return"Minified React error #"+z+"; visit "+te+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}var h={isMounted:function(){return!1},enqueueForceUpdate:function(){},enqueueReplaceState:function(){},enqueueSetState:function(){}},g={};function y(z,te,ue){this.props=z,this.context=te,this.refs=g,this.updater=ue||h}y.prototype.isReactComponent={},y.prototype.setState=function(z,te){if(typeof z!="object"&&typeof z!="function"&&z!=null)throw Error(d(85));this.updater.enqueueSetState(this,z,te,"setState")},y.prototype.forceUpdate=function(z){this.updater.enqueueForceUpdate(this,z,"forceUpdate")};function x(){}x.prototype=y.prototype;function w(z,te,ue){this.props=z,this.context=te,this.refs=g,this.updater=ue||h}var C=w.prototype=new x;C.constructor=w,e(C,y.prototype),C.isPureReactComponent=!0;var k={current:null},_=Object.prototype.hasOwnProperty,R={key:!0,ref:!0,__self:!0,__source:!0};function T(z,te,ue){var oe,ae={},ee=null,re=null;if(te!=null)for(oe in te.ref!==void 0&&(re=te.ref),te.key!==void 0&&(ee=""+te.key),te)_.call(te,oe)&&!R.hasOwnProperty(oe)&&(ae[oe]=te[oe]);var pe=arguments.length-2;if(pe===1)ae.children=ue;else if(1<pe){for(var ve=Array(pe),ne=0;ne<pe;ne++)ve[ne]=arguments[ne+2];ae.children=ve}if(z&&z.defaultProps)for(oe in pe=z.defaultProps,pe)ae[oe]===void 0&&(ae[oe]=pe[oe]);return{$$typeof:t,type:z,key:ee,ref:re,props:ae,_owner:k.current}}function W(z,te){return{$$typeof:t,type:z.type,key:te,ref:z.ref,props:z.props,_owner:z._owner}}function N(z){return typeof z=="object"&&z!==null&&z.$$typeof===t}function G(z){var te={"=":"=0",":":"=2"};return"$"+z.replace(/[=:]/g,function(ue){return te[ue]})}var L=/\/+/g;function M(z,te){return typeof z=="object"&&z!==null&&z.key!=null?G(""+z.key):te.toString(36)}function D(z,te,ue,oe,ae){var ee=typeof z;(ee==="undefined"||ee==="boolean")&&(z=null);var re=!1;if(z===null)re=!0;else switch(ee){case"string":case"number":re=!0;break;case"object":switch(z.$$typeof){case t:case n:re=!0}}if(re)return re=z,ae=ae(re),z=oe===""?"."+M(re,0):oe,Array.isArray(ae)?(ue="",z!=null&&(ue=z.replace(L,"$&/")+"/"),D(ae,te,ue,"",function(ne){return ne})):ae!=null&&(N(ae)&&(ae=W(ae,ue+(!ae.key||re&&re.key===ae.key?"":(""+ae.key).replace(L,"$&/")+"/")+z)),te.push(ae)),1;if(re=0,oe=oe===""?".":oe+":",Array.isArray(z))for(var pe=0;pe<z.length;pe++){ee=z[pe];var ve=oe+M(ee,pe);re+=D(ee,te,ue,ve,ae)}else if(ve=f(z),typeof ve=="function")for(z=ve.call(z),pe=0;!(ee=z.next()).done;)ee=ee.value,ve=oe+M(ee,pe++),re+=D(ee,te,ue,ve,ae);else if(ee==="object")throw te=""+z,Error(d(31,te==="[object Object]"?"object with keys {"+Object.keys(z).join(", ")+"}":te));return re}function j(z,te,ue){if(z==null)return z;var oe=[],ae=0;return D(z,oe,"","",function(ee){return te.call(ue,ee,ae++)}),oe}function X(z){if(z._status===-1){var te=z._result;te=te(),z._status=0,z._result=te,te.then(function(ue){z._status===0&&(ue=ue.default,z._status=1,z._result=ue)},function(ue){z._status===0&&(z._status=2,z._result=ue)})}if(z._status===1)return z._result;throw z._result}var q={current:null};function B(){var z=q.current;if(z===null)th ...
